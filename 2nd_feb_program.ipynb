# %% [markdown]
# <a href="https://colab.research.google.com/github/akbersaifudeen/advanced-python/blob/main/2nd_feb_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
("hello world.")
# Out:
# 'hello world.'

# %%
("hello world")
# Out:
# 'hello world'

# %%
print("hello world")
# Out:
# helloworld

# %%
n
# Out:
# Enter your nameakber

# %%
age = input("Enter your age")
# Out:
# Enter your age21

# %%
address = input("Enter your address")
# Out:
# Enter your addresspazhaytheruvil veedu vilakkupara po yeroor

# %%
DOB = input("enter your DOB")
# Out:
# enter your DOB17 feb 2005

# %%
phone_no = input("Enter your phone_no")
# Out:
# Enter your phone_no6238994950

# %%
print(f"name : {name}");
print(f"age: {age}");
print(f"address : {address}");
print(f"DOB : {DOB}");
print(f"phone_no : {phone_no}");
# Out:
# name : akber
# age: 21
# address : akber manzil
# DOB : 17 feb 2005
# phone_no : 6238994950

# %%
first_name = "akber"
last_name ="saifudeen"
Full_name = first_name+" "+last_name
print(Full_name)
# Out:
# akber saifudeen

# %%
news = "Global markets surge following unexpected tech sector growth and positive investor sentiment in early trading hours."
print(len(news))
# Out:
# 116

# %%
news[8]
# Out:
# 'a'

# %%
news[15:20]
# Out:
# 'surge'

# %%
news[0:22]
# Out:
# 'Global markets surge f'

# %%
news[:15]
# Out:
# 'Global markets '

# %%
news.upper()
# Out:
# 'GLOBAL MARKETS SURGE FOLLOWING UNEXPECTED TECH SECTOR GROWTH AND POSITIVE INVESTOR SENTIMENT IN EARLY TRADING HOURS.'

# %%
news.lower()
# Out:
# 'global markets surge following unexpected tech sector growth and positive investor sentiment in early trading hours.'

# %%
news.strip()
# Out:
# 'Global markets surge following unexpected tech sector growth and positive investor sentiment in early trading hours.'

# %%
news.split()
# Out:
# ['Global',
#  'markets',
#  'surge',
#  'following',
#  'unexpected',
#  'tech',
#  'sector',
#  'growth',
#  'and',
#  'positive',
#  'investor',
#  'sentiment',
#  'in',
#  'early',
#  'trading',
#  'hours.']

# %%
news.capitalize()
# Out:
# 'Global markets surge following unexpected tech sector growth and positive investor sentiment in early trading hours.'

# %%
num1 = 20
num2 = 6
print (num1+num2)
# Out:
# 26

# %%
num1-num2
# Out:
# 14

# %%
num1//num2
# Out:
# 3

# %%
num1**num2
# Out:
# 64000000

# %%
num1 > num2
# Out:
# True

# %%
num2< num1
# Out:
# True

# %%
num1 == num2
# Out:
# False

# %%
print(10>5 and 7>2)
# Out:
# True

# %%
print(not(10>5 and 7>2))
# Out:
# False

# %%
#in, not in

news
Global markets surge following unexpected tech sector growth and positive investor sentiment in early trading hours.

# %%
print("tech in news")
# Out:
# tech in news

# %%
num1 = input("Enter your salary")
# Out:
# Enter your salary15000

# %%
num2 = input("Enter your expense")
# Out:
# Enter your expense10000

# %%
savings = ("num1-num2")

# %%
print()

# %%
num1 = int (input("Enter your salary"))
num2 = int (input("Enter your expense"))
savings = num1-num2
print(f"your savings in {savings}")
# Out:
# Enter your salary15000
# Enter your expense5000
# your savings in 10000

# %%
# Out:
# Enter the amount10000
# Enter the worker10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-326459885.py in <cell line: 0>()
#       1 Amount= int(input("Enter the amount"))
#       2 worker= int(input("Enter the worker"))
# ----> 3 print(worker/amount)
#       4 print(amount/worker)
#
# NameError: name 'amount' is not defined

# %%
num1 = int(input("enter the amount"))
num2 = 4000
print(num1>=num2)
print(num1%5)
print(num1//5)
# Out:
# enter the amount10000
# True
# 0
# 2000

# %%
playlist = ["jhol","kunfaya","kalyani"]
print(playlist)
# Out:
# ['jhol', 'kunfaya', 'kalyani']

# %%
type(groceries)
# Out:
# list

# %%
playlist[0]
# Out:
# 'jhol'

# %%
playlist[-1]
# Out:
# 'kalyani'

# %%
len(playlist)
# Out:
# 3

# %%
new_playlist = ["pop","metal","phonk"]

final_list = playlist + new_playlist
final_list
# Out:
# ['jhol', 'kunfaya', 'kalyani', 'pop', 'metal', 'phonk']

# %%
new_playlist2 = ["kalyani","vatilil"]
final_list.extend(new_playlist2)

# %%
final_list
# Out:
# ['jhol', 'kunfaya', 'kalyani', 'pop', 'metal', 'phonk', 'kalyani', 'vatilil']

# %%
 final_list.append("kalyani")

# %%
 final_list. insert(2,"metal")

# %%
 final_list.reverse()

# %%
 final_list.sort()

# %%
 final_list.pop()
# Out:
# 'orange'

# %%
 final_list.pop(2)
# Out:
# 'biscuits'

# %%
 final_list.clear()

# %%
 final_list
# Out:
# []

# %%
final_list = playlist.extend(new_list)

# %%
nums = [10,23,83,99,13,90,43,76]

# %%
max(nums)
# Out:
# 99

# %%
sum(nums)
# Out:
# 437

# %%
fruits = ("apple","banana","orange")
type(fruits)
# Out:
# tuple

# %%
veggies =("carrot","potato","tomato")
type (veggies)
# Out:
# tuple

# %%
fruits += veggies

# %%
fruits
# Out:
# ('apple',
#  'banana',
#  'orange',
#  'carrot',
#  'potato',
#  'tomato',
#  'carrot',
#  'potato',
#  'tomato')

# %%
fruits = {"apple","banana","orange","lemon","apple"}
type(fruits)
# Out:
# set

# %%
fruits
# Out:
# {'apple', 'banana', 'lemon', 'orange'}

# %%
vegs = ["onion","tomato"]

# %%
fruits
# Out:
# {'apple', 'banana', 'lemon', 'orange'}

# %%
fruits.remove("apple")#discard
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-868329600.py in <cell line: 0>()
# ----> 1 fruits.remove("apple")#discard
#
# KeyError: 'apple'

# %%
fruits
# Out:
# {'banana', 'lemon', 'orange'}

# %%
car = {
    "brand": "ford",
    "model": "mustang",
    "year" : 2025,
   "cur_year": 2025
}
car
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 2025, 'cur_year': 2025}

# %%
car["brand"]
# Out:
# 'ford'

# %%
car2=dict(brand="maruthi",model="swift",year=2020)
car2
# Out:
# {'brand': 'maruthi', 'model': 'swift', 'year': 2020}

# %%
car["model"]
# Out:
# 'mustang'

# %%
car.get("brand")
# Out:
# 'ford'

# %%
len(car2)
# Out:
# 3

# %%
car2.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
car2.values()
# Out:
# dict_values(['maruthi', 'swift', 2020])

# %%
car2['model']= "Auto"
car2
{'brand':'maruthi','model':'Alto','year': 2020}
# Out:
# {'brand': 'maruthi', 'model': 'Alto', 'year': 2020}

# %%
car2['color']="grey"
car2
# Out:
# {'brand': 'maruthi', 'model': 'Auto', 'year': 2020, 'color': 'grey'}

# %%
car2.items()
# Out:
# dict_items([('brand', 'maruthi'), ('model', 'Auto'), ('year', 2020), ('color', 'black'), ('cylinders', 6), ('engine', 'petrol')])

# %%
car.popitem()
car2.pop("2020")
del car2['petrol']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-634001611.py in <cell line: 0>()
# ----> 1 car.popitem()
#       2 car2.pop("2020")
#       3 del car2['petrol']
#
# KeyError: 'popitem(): dictionary is empty'

# %%
car2
# Out:
# {'brand': 'maruthi',
#  'model': 'Auto',
#  'year': 2020,
#  'color': 'black',
#  'cylinders': 6,
#  'engine': 'petrol'}

# %%
car
# Out:
# {}

# %%
emp1 = {"Name":"Raj",
       "Salary":45000,
       "dept":"HR"}
emp2 = {"Name":"Anu",
       "Salary":30000,
       "dept":"manager"}
emp3 = {"Name":"Anoop",
       "Salary":20000,
       "dept":"finance manager"}

employees= {"employee1":emp1,
                    "employee2":emp2,
                    "employee3":emp3}

employees
# Out:
# {'employee1': {'Name': 'Raj', 'Salary': 45000, 'dept': 'HR'},
#  'employee2': {'Name': 'Anu', 'Salary': 30000, 'dept': 'manager'},
#  'employee3': {'Name': 'Anoop', 'Salary': 20000, 'dept': 'finance manager'}}

# %%
employees = ()

# %%
Contact_book = {
     "asif" : 7899,
    "abdulla": 2322,
    "ashkar" : 9394,
    "asim": 76767,
    "aadhil":9889
}
Contact_book
# Out:
# {'asif': 7899, 'abdulla': 2322, 'ashkar': 9394, 'asim': 76767, 'aadhil': 9889}

# %%
Contact_book.update({"asim":696969,"asif": 22222})
Contact_book
# Out:
# {'asif': 22222,
#  'abdulla': 2322,
#  'ashkar': 9394,
#  'asim': 696969,
#  'aadhil': 9889}

# %%
del Contact_book["aadhil"]
Contact_book
# Out:
# {'asif': 22222, 'abdulla': 2322, 'ashkar': 9394, 'asim': 696969}

# %%
Contact_book.keys()
# Out:
# dict_keys(['asif', 'abdulla', 'ashkar', 'asim'])

# %%
movies = ["avatar","titanic","rrr"]
ratings = [9.0,7.8,8.0,]

movie_ratings = dict(zip(movies,ratings))
movie_ratings
# Out:
# {'avatar': 9.0, 'titanic': 7.8, 'rrr': 8.0}

# %%
a=5
b=1
if a>b:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# a is greater than b

# %%
student_mark=int(input("enter your mark"))
if student_mark>90:
    print("A")
elif student_mark>70:
    print("B")
elif student_mark >50:
    print("C")3
elif student_mark>30:
    print("D")
else:
    print("F")
# Out:
# enter your mark23
# F

# %%
weather =input("enter the weather")
if weather == "rainy":
    print("take umbrella")
if weather == "sunny":
    print("take sunglass")
if weather == "cloudy":
    print("take raincoat")
# Out:
# enter the weathercloudy
# take raincoat

# %%
marks = 45
resukt = "pass" if marks >= 40 else "fail"
print(result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3319018596.py in <cell line: 0>()
#       1 marks = 45
#       2 resukt = "pass" if marks >= 40 else "fail"
# ----> 3 print(result)
#
# NameError: name 'result' is not defined

# %%
age=20
education = "high school"
if age > 18:
    if education == "higher secondary":
        print("eligible for higher secondary program")
    else:
        print("not eligible")
# Out:
# not eligible

# %%
marks = 45
result = "pass" if marks>30 else"fail"
if result =="pass":
print("awaraded with a grade")
else:
  print("no awards")
# Out:
#   File "/tmp/ipython-input-3626906792.py", line 4
#     print("awaraded with a grade")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
temp = 32

weather = {"status":"hot" if temp >30 else "cold"}
{'status':"hot"}
# Out:
# {'status': 'hot'}

# %%
list = {2000,300,200,50,100}
total =sum(list)
print(total)
if total>2000:
  price=( "you have saved"),(total/100*20)
elif (total>1000):
    price=( "you have saved"),(total/100*10)
else:
      print( "not saved")
      print=("final bill amount")
# Out:
# 2650

# %%
fruits = ["apple","banana","orange"]
for fr in fruits:
  print(fr)
# Out:
# apple
# banana
# orange

# %%
for i in range(10):
  print(f"square of {i} is {i**2}")
# Out:
# square of 0 is 0
# square of 1 is 1
# square of 2 is 4
# square of 3 is 9
# square of 4 is 16
# square of 5 is 25
# square of 6 is 36
# square of 7 is 49
# square of 8 is 64
# square of 9 is 81

# %%
grocery_list =["apple","banana","milk","bread","eggs"]

for item in grocery_list:
  if item == 'milk':
    print("item, present") # Indented and typo 'itemp' fixed to 'item'
    break
else:
  if item =="banana":
    print("item not found")
# Out:
# item, present

# %%
savings = [2000,2500,0,3000,1000,5000]
for i in savings:
  if i>4000:
   print(f"savings is greater than 4000 and your savings is {i}")
# Out:
# savings is greater than 4000 and your savings is 5000

# %%
savings=[2000,2500,0,3000,1000,5000]
for i in savings:
  continue
  if i>4000:
    printf("4000(i)")
    i+=t
print(f"savings is (t)")
# Out:
# savings is (t)

# %%
numbers =["989898989"],"121344","8686958598","9595959599","95954949439"
for i in numbers:
  if len(i)==10:
   print(i)
# Out:
# 8686958598
# 9595959599

# %%
numbers =["989898989","121344","8686958598","9595959599","95954949439"]
for i in numbers:
  if len(i)==10:
   print(f"{i} is valid")
  else:
    print(f"{i} is invalid")
# Out:
# 989898989 is invalid
# 121344 is invalid
# 8686958598 is valid
# 9595959599 is valid
# 95954949439 is invalid

# %%
numbers =["989898989"],"121344","8686958598","9595959599","95954949439"
valid=0
invalid_count=0
for i in numbers:
  if len(i)==10:
    print("valid")
    valid+=1
    continue
    else:
      print("invalid")
      invalid_count+=1
      valid_numbers
# Out:
#   File "/tmp/ipython-input-2821986350.py", line 9
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
i=1
while i<10:
  print(i**1)
  i +=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
savings_goal=10000
current_sav = 0

monthly_deps = 15000

months = 0
while  current_sav <savings_goal:
   current_sav += monthly_dep
   months+=1
else:
  print("you have reached the goal")

  print(f"it will take {months} to achieve your goal of {savings_goal}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-524805075.py in <cell line: 0>()
#       6 months = 0
#       7 while  current_sav <savings_goal:
# ----> 8    current_sav += monthly_dep
#       9    months+=1
#      10 else:
#
# NameError: name 'monthly_dep' is not defined

# %%
students_grades = {"anu":85,"Bob":63,"john":45,"vani":55,"akber":52}
for i in students_grades.keys():
  print(i)
# Out:
# anu
# Bob
# john
# vani
# akber

# %%
for i in students_grades.values():
  print(i)
# Out:
# 85
# 63
# 45
# 55
# 52

# %%
for i,j in students_grades.items():
  print(i,":",j)
  if j >50:
   print(f"{i}scored A grade")
  else:
   print(f"{i}scored B grade")
# Out:
# anu : 85
# anuscored A grade
# Bob : 63
# Bobscored A grade
# john : 45
# johnscored B grade
# vani : 55
# vaniscored A grade
# akber : 52
# akberscored A grade

# %%
emp1 = {"Name":"Raj",
       "Salary":45000,
       "dept":"HR"}
emp2 = {"Name":"Anu",
       "Salary":30000,
       "dept":"manager"}
emp3 = {"Name":"Anoop",
       "Salary":20000,
       "dept":"finance manager"}

employees= {"employee1":emp1,
                    "employee2":emp2,
                    "employee3":emp3}

employees
# Out:
# {'employee1': {'Name': 'Raj', 'Salary': 45000, 'dept': 'HR'},
#  'employee2': {'Name': 'Anu', 'Salary': 30000, 'dept': 'manager'},
#  'employee3': {'Name': 'Anoop', 'Salary': 20000, 'dept': 'finance manager'}}

# %%
for emcode,empdetail in employees.items(:)
for k,val in empdetails:
  {'employee1': {'Name': 'Raj', 'Salary': 45000, 'dept': 'HR'},
 'employee2': {'Name': 'Anu', 'Salary': 30000, 'dept': 'manager'},
 'employee3': {'Name': 'Anoop', 'Salary': 20000, 'dept': 'finance manager'}}
# Out:
#   File "/tmp/ipython-input-2134450600.py", line 1
#     for emcode,empdetail in employees.items(:)
#                                             ^
# SyntaxError: invalid syntax

# %%
for emcode,empdetail in employees.items(:)
for k,val in empdetails():
  if k=="Name" and val=="Raj":
    print("raj found")
# Out:
#   File "/tmp/ipython-input-549916086.py", line 1
#     for emcode,empdetail in employees.items(:)
#                                             ^
# SyntaxError: invalid syntax

# %%
for num in range(100, 801):
    if num % 3 == 0 and num % 7 == 0:
        print(num)
# Out:
# 105
# 126
# 147
# 168
# 189
# 210
# 231
# 252
# 273
# 294
# 315
# 336
# 357
# 378
# 399
# 420
# 441
# 462
# 483
# 504
# 525
# 546
# 567
# 588
# 609
# 630
# 651
# 672
# 693
# 714
# 735
# 756
# 777
# 798

# %%
for i in range(1, 16):
    if i % 2 == 0:
        print(i, "-even")
    else:
        print(i, "-odd")
# Out:
# 1 -odd
# 2 -even
# 3 -odd
# 4 -even
# 5 -odd
# 6 -even
# 7 -odd
# 8 -even
# 9 -odd
# 10 -even
# 11 -odd
# 12 -even
# 13 -odd
# 14 -even
# 15 -odd

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

print("The largest number is:", largest)
# Out:
# Enter first number: 2
# Enter second number: 3
# Enter third number: 4
# The largest number is: 4

# %%
for i in range(1, 6):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
count = 0

for num in range(1, 1001):
    if num % 8 == 0:
        count += 1

print("Count of numbers divisible by 8 from 1 to 1000 is", count)
# Out:
# Count of numbers divisible by 8 from 1 to 1000 is 125

# %%
def mutliply(num):
 print(num*2)
multiply(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3550697354.py in <cell line: 0>()
#       1 def mutliply(num):
#       2  print(num*2)
# ----> 3 multiply(10)
#
# NameError: name 'multiply' is not defined

# %%
def send_gift(recipient, gift):
   print(f"Sending {gift} to {recipient}")
send_gift("Alice", "a Watch")
# Out:
# Sending a Watch to Alice

# %%
def send_gift(recipient,gift):
  print(f"sendinG{gift} to {recipient}")
   send_gift(gift="a camera, recipient= bob")
# Out:
#   File "/tmp/ipython-input-1415330053.py", line 3
#     send_gift(gift="a camera, recipient= bob")
#     ^
# IndentationError: unexpected indent

# %%
f send_gift(recipient,gift)="a box"):
  print(f"sendinG{gift} to {recipient}")
   send_gift("vani")
# Out:
#   File "/tmp/ipython-input-1098476090.py", line 1
#     f send_gift(recipient,gift)="a box"):
#                                        ^
# SyntaxError: unmatched ')'

# %%
frozenset() hasattr() vars() enum.bin()

# %%
def book_trip(destination, transport):
    print(f"Booking a {transport} to {destination}.")

book_trip("Paris", "Flight")
# Out:
# Booking a Flight to Paris.

# %%
def book_trip(destination, transport):
    print(f"Booking a {transport} to {destination}.")

book_trip(destination="Paris",transport="Flight")
# Out:
# Booking a Flight to Paris.

# %%
  def book_trip(destination,transport="bus"):
    print(f"Booking a {transport} to {destination}.")

book_trip("newyork","plane")
# Out:
# Booking a plane to newyork.

# %%
def pack(destination, *items):
    print(f"Packing for {destination}:")
    for item in items:
        print(f"- {item}")

pack("Hawaii", "Swimsuit", "Sunscreen", "sunglass", "Hat")
# Out:
# Packing for Hawaii:
# - Swimsuit
# - Sunscreen
# - sunglass
# - Hat

# %%
def add_numbers(a,b):
  print(a+b)
result= add_numbers(5,5)
# Out:
# 10

# %%
def add_numbers(a,b)
return a+b
# Out:
#   File "/tmp/ipython-input-1430265866.py", line 1
#     def add_numbers(a,b)
#                         ^
# SyntaxError: expected ':'

# %%
def add_ten(numbers):
  print(numbers+10)
my_result = add_ten(5)
final_answers = my result*2
print(f"the final answer is:{final_answer}")
# Out:
#   File "/tmp/ipython-input-2160806281.py", line 4
#     final_answers = my result*2
#                        ^
# SyntaxError: invalid syntax

# %%
def add_ten(num):
  return(num+10)
my_result = add_ten(5)
final_answers=my_result*2
print(f"the final_answers is:{final_answers}")
# Out:
# the final_answers is:30

# %%
def square(x)
sq = x*x
return sq

square(5)
# Out:
#   File "/tmp/ipython-input-498745511.py", line 1
#     def square(x)
#                  ^
# SyntaxError: expected ':'

# %%
sqaure = lambda x,x*x
square(5)
# Out:
#   File "/tmp/ipython-input-3098848766.py", line 1
#     sqaure = lambda x,x*x
#                        ^
# SyntaxError: invalid syntax

# %%
addition=lambda x,y:x+y
addition(10,20)
# Out:
# 30

# %%
is_pass = lambda marks:"pass" if marks>40 else "fail"
is_pass(30)
# Out:
# 'fail'

# %%
def square(x):
 sq = x * x
 return sq

numbers = [1,2,3,4,5]
squares = map(square,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers = [1,2,3,4,5]
squares = map(lambda x:x*x,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a = [1,2,3,]
list_b = [4,5,6]
sum_lists = list(map(lambda x,y:x+y ,list_a,list_b))
sum_lists
# Out:
# [5, 7, 9]

# %%
adzz=[9,-1,3,7,8,-5,11]
positive_list=list(filter(lambda x:x>0,adzz))
positive_list
# Out:
# [9, 3, 7, 8, 11]

# %%
git hub codes
,,,,,,,,,,,,,,,,,,,,,,,,,
git init
git clone
git pull
git status
git add
git commit
git push
merge
# Out:
#   File "/tmp/ipython-input-4097438396.py", line 1
#     git hub codes
#         ^
# SyntaxError: invalid syntax
